# %% [markdown]
# # Introduction to Data Visualization with Matplotlib
#
# Matplotlib - a python library that is widely used for data visuzalization
#
# Advantage: customize the properties of visualization and other plots based on your data.

# %% [markdown]
# ## To import the library
#
#         import matplotlib.pyplot as plt
#         fig, ax = plt.subplots()
#         plt.show() # empty plot
#
#  Adding data to axes
#
#         ax.plot(seattle_weather['MONTH'], seattle_weather['MLY-TAVG-NORMAL'])
#         plt.show()
#  ![viz1](media/viz1.png)
#
#  Adding another plot to the existing plot
#
#         fig, ax = plt.subplots()
#         ax.plot(seattle_weather['MONTH'], seattle_weather['MLY-TAVG-NORMAL'])
#
#  Putting all together
#
#         ax.plot(seattle_weather['MONTH'], seattle_weather['MLY-TAVG-NORMAL'])
#         ax.plot(austin_weather['MONTH'], austin_weather['MLY-TAVG-NORMAL'])
#         plt.show()
#
#  ![viz2](media/viz2.png)

# %% [markdown]
# ## Customizing your plots
#
#
#
# ax.set_xlabel()
# ax.set_ylabel()
# ax.set_title()
